# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pip install scikit-learn
import sklearn.linear_model 
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
x = df["area"]
x
y = df.price
y
x2 = pd.DataFrame(x)
print(x2)
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
model = LinearRegression()

# %%
model.fit(x2, y)
# Out:
# LinearRegression()

# %%
model.predict([[3200]])
# Out:
# c:\Users\komal\OneDrive\Desktop\rohan hw\myenv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([615136.98630137])

# %%
plt.scatter(x2, y, color='blue',marker='*')
plt.xlabel("Price")
plt.ylabel("Area")
plt.title("Price vs Area")
plt.plot(x2, model.predict(x2), color='red')
plt.show()

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
(135.78767123*3200)+ 180616.43835616432
# Out:
# 615136.9862921643

# %%
df = pd.read_csv("canada_per_capita_income.csv")
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
x = df["year"]
x
y = df["per capita income (US$)"]
y
x2 = pd.DataFrame(x)
print(x2)
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
model1 = LinearRegression()
model1.fit(x2, y)
model1.predict([[1984]])
# Out:
# c:\Users\komal\OneDrive\Desktop\rohan hw\myenv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11463.9513864])

# %%
plt.scatter(x, y, color='pink')
plt.xlabel("Price")
plt.ylabel("Quantity")
plt.title("Price vs Quantity")
plt.plot(x2, model1.predict(x2), color='brown')
plt.show()

# %%
model1.coef_
# Out:
# array([828.46507522])

# %%
model1.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %%
model1.predict([[2017]])
# Out:
# c:\Users\komal\OneDrive\Desktop\rohan hw\myenv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([38803.29886875])

# %%
# y = mx + b
(828.46507522*2017) + -1632210.7578554576
# Out:
# 38803.29886328266

# %%
df = pd.read_csv("homeprices2.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.bedrooms = df.bedrooms.fillna(df.bedrooms.median())
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
from sklearn import linear_model

reg = linear_model.LinearRegression()
reg.fit(df.drop('price', axis='columns'), df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
reg.intercept_
# Out:
# np.float64(221323.00186540437)

# %%
# Predicting price for a house with 3000 sqft area, 3 bedrooms, and 40 age
reg.predict([[3000, 3, 40]])
# Out:
# c:\Users\komal\OneDrive\Desktop\rohan hw\myenv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([498408.25158031])

# %%
112.06244194*3000 + 23388.88007794*3 + -3231.32803281*40 + 221323.00186540437
# Out:
# 498423.8466068244

# %%
# find price of a house with 2500 sqft area, 4 bedrooms, and 5 age
reg.predict([[2500,4,5]])
# Out:
# c:\Users\komal\OneDrive\Desktop\rohan hw\myenv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([578876.03748933])
